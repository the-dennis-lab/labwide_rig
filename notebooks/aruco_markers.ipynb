# %%
import cv2
import os, sys, math
import matplotlib.pyplot as plt

# %%
cv2.aruco_Dictionary
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 cv2.aruco.drawMarker
#
# AttributeError: module 'cv2.aruco' has no attribute 'drawMarker'
